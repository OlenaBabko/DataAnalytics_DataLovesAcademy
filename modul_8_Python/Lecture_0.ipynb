# %% [markdown]
# # Вступ
# Мене звати Олена!
# Я пишу код на Python!
# Ця програма робить щось корисне.

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
120+20
# Out:
# 140

# %% [markdown]
# # Розділ 1
#
# ## Підрозділ
#
# текст

# %%
# !ls
# Out:
# Applications    Downloads       Movies          Pictures
# Desktop         Lecture_0.ipynb Music           Public
# Documents       Library         OneDrive

# %%
import time

for i in range(10):
    print(i)
    time.sleep(30)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       3 for i in range(10):
#       4     print(i)
# ----> 5     time.sleep(30)
#
# KeyboardInterrupt:

# %%
my_list = [1, 2, 3, 4]

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # Розділ 2
# текст не список ((

# %%
[x**2 for x in range(-10, 11)]
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
s = 'Hello world!'

# %%
print(s)
# Out:
# Hello world!

# %%
1+1
print(2+22)
3+3
s
# Out:
# 24
# 'Hello world!'

# %%
a = 'Hello everyone!'

# %%
a
# Out:
# 'Hello everyone!'

# %%
a.lower()
# Out:
# 'hello everyone!'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.sin(range(50)));

# %%
a = 1
b = 2
a + b
# Out:
# 3

# %%
a/b
# Out:
# 0.5
